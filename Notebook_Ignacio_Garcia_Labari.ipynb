# %% [markdown]
# # NOTEBOOK IGNACIO GARCIA LABARI

# %%
import pandas as pd               #importo la biblioteca PANDAS para poder usar sus funciones

# %%
pd.read_csv("ecoli.data").head() # abro el archivo 

# Attribute Information: 
# protein: Accession number for the SWISS-PROT database.
# mcg: McGeoch's method for signal sequence recognition.
# gvh: Von Heijne's method for signal sequence recognition.
# lip: Von Heijne's Signal Peptidase II consensus sequence score.
# chg: Presence of charge on N-terminus of predicted lipoproteins.
# aac: Score of discriminant analysis of the amino acid content of outer membrane and periplasmic proteins.
# alm1: Score of the ALOM membrane spanning region prediction program.
# alm2: Score of ALOM program after excluding putative cleavable signal regions from the sequence.
# site: Localization site: cp (cytoplasm); im (inner membrane without signal sequence);
# pp (perisplasm); imU (inner membrane, uncleavable signal sequence); om (outer membrane);
# omL (outer membrane lipoprotein); imL (inner membrane lipoprotein); imS (inner membrane, cleavable signal sequence).
# Out:
#       protein   mcg   gvh   lip  chg   aac  alm1  alm2 site
# 0   AAT_ECOLI  0.49  0.29  0.48  0.5  0.56  0.24  0.35   cp
# 1  ACEA_ECOLI  0.07  0.40  0.48  0.5  0.54  0.35  0.44   cp
# 2  ACEK_ECOLI  0.56  0.40  0.48  0.5  0.49  0.37  0.46   cp
# 3  ACKA_ECOLI  0.59  0.49  0.48  0.5  0.52  0.45  0.36   cp
# 4   ADI_ECOLI  0.23  0.32  0.48  0.5  0.55  0.25  0.35   cp

# %%
# Fuente del dataset: https://archive.ics.uci.edu/ml/datasets/Ecoli
# Dicha data estaba separada por espacios y no por comas y no tenía los títulos.
# Para lograr obtener lo que se ve en el notebook lo que hice fue utilizar la consola de 
# linux para abrir un programa de edición de textos llamado "vim". Use la siguiente expresión
# regular: %s/ \+/,/g    significados:  %(en toda la línea) s(sustituí) /un espacio\
# (donde haya un espacio) +/ (o más de uno) /,/ (reemplazalo por solamente una coma)
# /g (g de global, es decir no solo a la primer línea, sino globalmente a todo el documento)
# y finalmente los títulos de las columnas fueron agregadas a mano.

ecoli = pd.read_csv("ecoli.data") # lo guardo en un objeto (asignación)

# %%
type(ecoli)
# Out:
# pandas.core.frame.DataFrame

# %%
ecoli.dtypes # para ver que tipo de cosas contiene mi dataframe uso la función dtypes

#object: significa que es un objeto (texto) osea una cadena de caracteres (string)
#float: significa que es un número con coma
# Out:
# protein     object
# mcg        float64
# gvh        float64
# lip        float64
# chg        float64
# aac        float64
# alm1       float64
# alm2       float64
# site        object
# dtype: object

# %%
ecoli.columns #para ver las columnas
# Out:
# Index(['protein', 'mcg', 'gvh', 'lip', 'chg', 'aac', 'alm1', 'alm2', 'site'], dtype='object')

# %%
# Para ver las dimensiones del dataframe utilizo la función shape:

ecoli.shape

# obtengo una tupla, por lo cual los datos son inmutables. 
# La misma me informa el n° de filas y el n° de columnas respectivamente.
# Out:
# (336, 9)

# %%
#puedo corroborarlo de la siguiente manera:

a = ecoli.shape
type(a)
# Out:
# tuple

# %%
ecoli.head() #con la función head veo las primeras 5 líneas de mi dataframe
# Out:
#       protein   mcg   gvh   lip  chg   aac  alm1  alm2 site
# 0   AAT_ECOLI  0.49  0.29  0.48  0.5  0.56  0.24  0.35   cp
# 1  ACEA_ECOLI  0.07  0.40  0.48  0.5  0.54  0.35  0.44   cp
# 2  ACEK_ECOLI  0.56  0.40  0.48  0.5  0.49  0.37  0.46   cp
# 3  ACKA_ECOLI  0.59  0.49  0.48  0.5  0.52  0.45  0.36   cp
# 4   ADI_ECOLI  0.23  0.32  0.48  0.5  0.55  0.25  0.35   cp

# %%
ecoli.tail() #con la función tail veo las últimas 5 líneas de mi dataframe
# Out:
#         protein   mcg   gvh   lip  chg   aac  alm1  alm2 site
# 331  TREA_ECOLI  0.74  0.56  0.48  0.5  0.47  0.68  0.30   pp
# 332  UGPB_ECOLI  0.71  0.57  0.48  0.5  0.48  0.35  0.32   pp
# 333  USHA_ECOLI  0.61  0.60  0.48  0.5  0.44  0.39  0.38   pp
# 334  XYLF_ECOLI  0.59  0.61  0.48  0.5  0.42  0.42  0.37   pp
# 335  YTFQ_ECOLI  0.74  0.74  0.48  0.5  0.31  0.53  0.52   pp

# %%
#para ver las líneas comprendidas entre las observaciones 200 y 215 hago así:

ecoli.head(216).tail(16) 

#uso PIPE(tuberia):la salida de un resultado, entra en otra función.
#hay que ponerlo así ya que los índices en python arrancan del número 0.
# Out:
#         protein   mcg   gvh   lip  chg   aac  alm1  alm2 site
# 200  PTGB_ECOLI  0.58  0.55  0.48  0.5  0.57  0.70  0.74   im
# 201  PTHB_ECOLI  0.36  0.47  0.48  0.5  0.51  0.69  0.72   im
# 202  PTMA_ECOLI  0.39  0.41  0.48  0.5  0.52  0.72  0.75   im
# 203  PTOA_ECOLI  0.35  0.51  0.48  0.5  0.61  0.71  0.74   im
# 204  PTTB_ECOLI  0.31  0.44  0.48  0.5  0.50  0.79  0.82   im
# 205  RODA_ECOLI  0.61  0.66  0.48  0.5  0.46  0.87  0.88   im
# 206  SECE_ECOLI  0.48  0.49  0.48  0.5  0.52  0.77  0.71   im
# 207  SECF_ECOLI  0.11  0.50  0.48  0.5  0.58  0.72  0.68   im
# 208  SECY_ECOLI  0.31  0.36  0.48  0.5  0.58  0.94  0.94   im
# 209  TNAB_ECOLI  0.68  0.51  0.48  0.5  0.71  0.75  0.78   im
# 210  XYLE_ECOLI  0.69  0.39  0.48  0.5  0.57  0.76  0.79   im
# 211  YCEE_ECOLI  0.52  0.54  0.48  0.5  0.62  0.76  0.79   im
# 212  EXBD_ECOLI  0.46  0.59  0.48  0.5  0.36  0.76  0.23   im
# 213  FTSL_ECOLI  0.36  0.45  0.48  0.5  0.38  0.79  0.17   im
# 214  FTSN_ECOLI  0.00  0.51  0.48  0.5  0.35  0.67  0.44   im
# 215  FTSQ_ECOLI  0.10  0.49  0.48  0.5  0.41  0.67  0.21   im

# %%
ecoli['protein'].head()  #selecciono una columna
# Out:
# 0     AAT_ECOLI
# 1    ACEA_ECOLI
# 2    ACEK_ECOLI
# 3    ACKA_ECOLI
# 4     ADI_ECOLI
# Name: protein, dtype: object

# %%
ecoli.protein.head() #otra forma de hacer lo mismo
# Out:
# 0     AAT_ECOLI
# 1    ACEA_ECOLI
# 2    ACEK_ECOLI
# 3    ACKA_ECOLI
# 4     ADI_ECOLI
# Name: protein, dtype: object

# %%
pd.unique(ecoli['site']) #para ver los diferentes sitios de localización q hay (no repetidos)
# Out:
# array(['cp', 'im', 'imS', 'imL', 'imU', 'om', 'omL', 'pp'], dtype=object)

# %%
sites = pd.unique(ecoli['site']) 

len(sites) #para contarlas
# Out:
# 8

# %%
ecoli['site'].nunique() #también se puede de esta manera # no hace falta grabar variable.
# Out:
# 8

# %%
 ## Por lo cual hay 8 sitios de localización diferentes para las proteínas de e.coli ##

ecoli.describe()    # para obtener estadísticas básicas de los valores numéricos del dataset
# Out:
#               mcg         gvh         lip         chg         aac        alm1  \
# count  336.000000  336.000000  336.000000  336.000000  336.000000  336.000000
# mean     0.500060    0.500000    0.495476    0.501488    0.500030    0.500179
# std      0.194634    0.148157    0.088495    0.027277    0.122376    0.215751
# min      0.000000    0.160000    0.480000    0.500000    0.000000    0.030000
# 25%      0.340000    0.400000    0.480000    0.500000    0.420000    0.330000
# 50%      0.500000    0.470000    0.480000    0.500000    0.495000    0.455000
# 75%      0.662500    0.570000    0.480000    0.500000    0.570000    0.710000
# max      0.890000    1.000000    1.000000    1.000000    0.880000    1.000000
#
#              alm2
# count  336.000000
# mean     0.499732
# std      0.209411
# min      0.000000
# 25%      0.350000
# 50%      0.430000
# 75%      0.710000
# max      0.990000

# %%
ecoli['alm1'].min() #para ver específicamente el valor mínimo de la columna 'alm1'
# Out:
# 0.029999999999999999

# %%
# Datos agrupados por sitios

data_agrupada = ecoli.groupby('site')

# %%
data_agrupada.describe() # Estadísticas para todas las columnas numéricas agrupadas por sitio
# Out:
#         aac                                                          alm1  \
#       count      mean       std   min     25%    50%     75%   max  count
# site
# cp    143.0  0.454476  0.087923  0.16  0.4100  0.450  0.5100  0.73  143.0
# im     77.0  0.536104  0.114123  0.00  0.4900  0.550  0.6000  0.74   77.0
# imL     2.0  0.455000  0.077782  0.40  0.4275  0.455  0.4825  0.51    2.0
# imS     2.0  0.535000  0.007071  0.53  0.5325  0.535  0.5375  0.54    2.0
# imU    35.0  0.558857  0.114783  0.06  0.5050  0.570  0.6350  0.75   35.0
# om     20.0  0.739000  0.093915  0.51  0.6950  0.745  0.8000  0.88   20.0
# omL     5.0  0.542000  0.111893  0.37  0.5200  0.540  0.6200  0.66    5.0
# pp     52.0  0.436731  0.085606  0.17  0.3900  0.440  0.4900  0.63   52.0
#
#                 ...    lip          mcg                                    \
#           mean  ...    75%   max  count      mean       std   min     25%
# site            ...
# cp    0.312657  ...   0.48  0.48  143.0  0.363566  0.123826  0.00  0.2700
# im    0.757532  ...   0.48  1.00   77.0  0.478442  0.194511  0.00  0.3400
# imL   0.645000  ...   1.00  1.00    2.0  0.725000  0.035355  0.70  0.7125
# imS   0.640000  ...   0.48  0.48    2.0  0.740000  0.155563  0.63  0.6850
# imU   0.744000  ...   0.48  1.00   35.0  0.726000  0.108552  0.47  0.6400
# om    0.462500  ...   0.48  1.00   20.0  0.672500  0.069424  0.52  0.6300
# omL   0.564000  ...   1.00  1.00    5.0  0.698000  0.044385  0.66  0.6700
# pp    0.468077  ...   0.48  0.48   52.0  0.652115  0.090344  0.29  0.6300
#
#
#         50%     75%   max
# site
# cp    0.360  0.4400  0.67
# im    0.490  0.6300  0.89
# imL   0.725  0.7375  0.75
# imS   0.740  0.7950  0.85
# imU   0.760  0.8100  0.88
# om    0.675  0.7325  0.78
# omL   0.680  0.7100  0.77
# pp    0.670  0.7000  0.76
#
# [8 rows x 56 columns]

# %%
data_agrupada.count()
# Out:
#       protein  mcg  gvh  lip  chg  aac  alm1  alm2
# site
# cp        143  143  143  143  143  143   143   143
# im         77   77   77   77   77   77    77    77
# imL         2    2    2    2    2    2     2     2
# imS         2    2    2    2    2    2     2     2
# imU        35   35   35   35   35   35    35    35
# om         20   20   20   20   20   20    20    20
# omL         5    5    5    5    5    5     5     5
# pp         52   52   52   52   52   52    52    52

# %%
data_agrupada.protein.count() # para ver solamente la columna de proteinas y me las cuente
# agrupadas por sitios
# Out:
# site
# cp     143
# im      77
# imL      2
# imS      2
# imU     35
# om      20
# omL      5
# pp      52
# Name: protein, dtype: int64

# %%
data_agrupada.protein.count().sort_values(ascending=False) #ordeno de > a <
# Out:
# site
# cp     143
# im      77
# pp      52
# imU     35
# om      20
# omL      5
# imS      2
# imL      2
# Name: protein, dtype: int64

# %%
## Puedo observar como es la distribución de las proteínas en los distintas localizaciones 
             # posibles de la bacteria e.coli ordenadas en forma descendente ##

# Puedo pedir especificamente la cantidad de proteínas que tiene un sitio determinado:
# Como por ejemplo la cantidad de proteínas citoplasmáticas de la bacteria.
data_agrupada.site.count()['cp']
# Out:
# 143

# %%
site_protein = ecoli.groupby(['site','protein'])                    #AGRUPO 2 COLUMNAS
site_protein.count().head()

# de esta manera puedo ver las proteínas que se encuentran en cada sitio
# Out:
#                  mcg  gvh  lip  chg  aac  alm1  alm2
# site protein
# cp   AAT_ECOLI     1    1    1    1    1     1     1
#      ACEA_ECOLI    1    1    1    1    1     1     1
#      ACEK_ECOLI    1    1    1    1    1     1     1
#      ACKA_ECOLI    1    1    1    1    1     1     1
#      ADI_ECOLI     1    1    1    1    1     1     1

# %%
site_protein.describe().head()
# Out:
#                   aac                                          alm1        \
#                 count  mean std   min   25%   50%   75%   max count  mean
# site protein
# cp   AAT_ECOLI    1.0  0.56 NaN  0.56  0.56  0.56  0.56  0.56   1.0  0.24
#      ACEA_ECOLI   1.0  0.54 NaN  0.54  0.54  0.54  0.54  0.54   1.0  0.35
#      ACEK_ECOLI   1.0  0.49 NaN  0.49  0.49  0.49  0.49  0.49   1.0  0.37
#      ACKA_ECOLI   1.0  0.52 NaN  0.52  0.52  0.52  0.52  0.52   1.0  0.45
#      ADI_ECOLI    1.0  0.55 NaN  0.55  0.55  0.55  0.55  0.55   1.0  0.25
#
#                  ...    lip         mcg                                    \
#                  ...    75%   max count  mean std   min   25%   50%   75%
# site protein     ...
# cp   AAT_ECOLI   ...   0.48  0.48   1.0  0.49 NaN  0.49  0.49  0.49  0.49
#      ACEA_ECOLI  ...   0.48  0.48   1.0  0.07 NaN  0.07  0.07  0.07  0.07
#      ACEK_ECOLI  ...   0.48  0.48   1.0  0.56 NaN  0.56  0.56  0.56  0.56
#      ACKA_ECOLI  ...   0.48  0.48   1.0  0.59 NaN  0.59  0.59  0.59  0.59
#      ADI_ECOLI   ...   0.48  0.48   1.0  0.23 NaN  0.23  0.23  0.23  0.23
#
#
#                   max
# site protein
# cp   AAT_ECOLI   0.49
#      ACEA_ECOLI  0.07
#      ACEK_ECOLI  0.56
#      ACKA_ECOLI  0.59
#      ADI_ECOLI   0.23
#
# [5 rows x 56 columns]

# %%
# %matplotlib inline # para que las imágenes aparezcan insertadas en el Notebook

# %%
localization = data_agrupada.protein.count()

# %%
grafica = localization.plot(kind='bar', title= "Proteins localization sites")
grafica.set_xlabel("sites")
grafica.set_ylabel("number of proteins")

# De esta manera puedo observar en un gráfico de barras como se distribuyen las distintas
# proteínas de E.coli en las diferentes localizaciónes celulares.
# Out:
# Text(0,0.5,'number of proteins')
